# %%
#mini projet
def calculePrixFinale(age, carteAbonnement, jourCenima):
    prix = 0
    if age < 18:
        prix = 8
    elif age >= 18 and age < 65:
        prix = 10
    elif age >= 65:
        prix = 7
    print('Le prix du billet est de :', prix)
    if carteAbonnement == 'Oui':
        prix = prix * 0.8
    if jourCinema == 'Mardi' or jourCenima == 'Mercredi':   
        prix = prix * 0.7
    print('Le prix final est de :', prix)
    
    return prix

print('Bonjour!')
print('-'*50)
age = input('Donnez moi votre age :') # tarif enfant(moin de 18ans): 8€ tarif adulte(18-64ans): 8€ tarif senior(65ans et plus): 7€ 
carteAbonnement =input('Est-ce que vous avez une carte d\'abonnement? (Oui/Non) : ') #20% de réduction sur le prix total
jourCinema = input('Quel jour de la semaine souhaitez-vous aller au cinéma? : ') #30% de reduction si le client vient le mardi ou le mecredi

#Afficher le prix du billet sans réductions. 
#Appliquer les réductions et afficher le prix final à payer
calculePrixFinale(int(age), carteAbonnement, jourCinema)
# Out:
# Bonjour!
# --------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 27
#      23 jourCinema = input('Quel jour de la semaine souhaitez-vous aller au cinéma? : ') #30% de reduction si le client vient le mardi ou le mecredi
#      25 #Afficher le prix du billet sans réductions.
#      26 #Appliquer les réductions et afficher le prix final à payer
# ---> 27 calculePrixFinale(int(age), carteAbonnement, jourCinema)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#Travaux pratiques
import math
import datetime
print('Exercise 1')

#création de la fonction de salutation
def salutation(prenom):
    print('Salut,', prenom)
    
listePrenom = ['Jean', 'Pierre', 'Paul', 'Jacques', 'Marie', 'Sophie', 'Julie', 'Julien', 'Julia', 'Juliette']
for prenom in listePrenom:
    salutation(prenom)

print('-'*50)

print('Exercise 2')

#creation de la fonction addition
def addition(n1, n2):
    return n1 + n2

print('La somme de 3 et 5 est :', addition(3, 5))

print('-'*50)

print('Exercise 3')

#création de la function de calcul d'age
def calculAge(annee_naissance):
    dateActuelle = datetime.datetime.now()
    age = dateActuelle.year - annee_naissance
    print('Vous avez', age, 'ans')
    
#test function de calcul d'age
calculAge(1990)
calculAge(2000)
calculAge(2007)
        
print('-'*50)

print('Exercise 4')

#création de la fonction calcul racine carrée
def racineCarree():
    n = input('Entrez un nombre : ')
    print('La racine carrée de', n, 'est :', math.sqrt(float(n))) #j'ai utilisé la fonction float() pour convertir le nombre en flottant
    
racineCarree()

print('-'*50)

print('Exercise 5')

print(datetime.datetime.now())

print('-'*50)

print('Exercise 6')

#création de la fonction de calcul surface d'un cercle

def surfaceCercle(rayon):
    return math.pi * rayon**2

print('La surface d\'un cercle de rayon 5 est :', surfaceCercle(5))

# %%
#Mini projet : jeu de devinette
import random

#fonction du jeu principal
def devinette():
    print('Bienvenue dans le jeu de devinette!')
    nombreMystere = random.randint(1, 100)
    print('Devinez le nombre mystère entre 1 et 100')
    nombre = 0
    nombreTentative = 10
    while nombre != nombreMystere and nombreTentative > 0:
        nombre = int(input('Entrez un nombre : '))  # Convert input to integer
        if nombre < nombreMystere:
            print('Le nombre mystère est plus grand')
            nombreTentative -= 1
            if nombreTentative == 0:
                print('Désolé! Vous avez épuisé toutes vos tentatives!')
                rejouer()
        elif nombre > nombreMystere:
            print('Le nombre mystère est plus petit')
            nombreTentative -= 1
            if nombreTentative == 0:
                print('Désolé! Vous avez épuisé toutes vos tentatives!')
                rejouer()
        elif nombre == nombreMystere:
            print('Bravo! Vous avez trouvé le nombre mystère!')
            rejouer()
        else:
            print('Nombre invalide! Veuillez entrer un nombre entre 1 et 100')
            nombreTentative -= 1
            if nombreTentative == 0:
                print('Désolé! Vous avez épuisé toutes vos tentatives!')
                rejouer()
        
        
#fonction de demande de rejouer au jeu
def rejouer():
    reponse = input('Voulez-vous rejouer? (Oui/Non) : ')
    if reponse == 'Oui':
        devinette()
    else:
        print('Merci d\'avoir joué!')

#test
devinette()

# %%
#Projet final : Gestionnaire de Banque Simplifié en Python 
#Objectif et travail attendu :
# Projet Final: Gestionnaire de Banque Simplifié
# Objectif : Créer une application Python qui simule un gestionnaire de comptes bancaires. L'utilisateur peut consulter le solde de son compte, déposer de l'argent, retirer de l'argent, et afficher l'historique des transactions.
# Fonctionnalités du projet :
# Création d'un compte :
# Demander à l'utilisateur de saisir son nom et de créer un compte avec un solde initial.
# Consultation du solde :
# L'utilisateur peut consulter le solde de son compte à tout moment.
# Dépôt d'argent :
# L'utilisateur peut déposer de l'argent sur son compte. Le montant est ajouté au solde.
# Retrait d'argent :
# L'utilisateur peut retirer de l'argent, à condition que le montant soit disponible sur son compte (le solde ne peut pas devenir négatif).
# Historique des transactions :
# Chaque dépôt ou retrait doit être enregistré dans l'historique des transactions, et l'utilisateur peut afficher cet historique.
# Menu d'options :
# L'utilisateur peut naviguer dans un menu avec différentes options (Consulter le solde, Déposer de l'argent, Retirer de l'argent, Afficher l'historique, Quitter).
# Ajout d’intérêts mensuels :
# Chaque mois, un taux d’intérêt est appliqué au solde du compte. Par exemple, un taux d’intérêt de 1% est ajouté au solde chaque mois.
# Le taux d’intérêt peut être défini lors de la création du compte.
# Possibilité de créer plusieurs comptes :
# L’utilisateur peut créer plusieurs comptes bancaires (par exemple, un compte épargne et un compte courant).
# L’utilisateur peut consulter, déposer, retirer, ou transférer de l’argent entre les différents comptes.
# Transfert d’argent entre comptes :
# L’utilisateur peut transférer de l’argent entre ses différents comptes (par exemple, transférer de l'argent d'un compte courant vers un compte épargne).
# Affichage des détails des comptes :
# L’utilisateur peut afficher une liste de tous ses comptes avec les soldes actuels et les taux d’intérêt associés.
# Ajout d’un code PIN pour chaque compte :
# Lors de la création de chaque compte, un code PIN est défini. Ce code PIN doit être saisi pour accéder au compte.

# Pseudo-code
# Fonction de création du compte :
# Demander le nom de l'utilisateur.
# Initialiser un solde à 0.
# Fonction pour consulter le solde :
# Afficher le solde actuel du compte.
# Fonction pour déposer de l'argent :
# Demander à l'utilisateur combien il souhaite déposer.
# Ajouter ce montant au solde.
# Fonction pour retirer de l'argent :
# Demander à l'utilisateur combien il souhaite retirer.
# Vérifier que le solde est suffisant.
# Retirer le montant du solde.
# Fonction pour afficher l'historique des transactions :
# Afficher la liste des dépôts et retraits effectués.
# Boucle principale :
# Afficher un menu d'options (1. Consulter le solde, 2. Déposer, 3. Retirer, 4. Historique, 5. Quitter).
# Répéter l'action choisie jusqu'à ce que l'utilisateur décide de quitter.
# Création de plusieurs comptes :
# Lors de la création, chaque compte a un nom unique, un solde initial, un taux d’intérêt et un code PIN.
# Application des intérêts mensuels :
# À chaque début de mois, un intérêt est calculé et ajouté au solde du compte.
# Transfert d’argent entre comptes :
# L’utilisateur peut sélectionner un compte source et un compte cible pour transférer de l’argent.
# Vérifier que le compte source a un solde suffisant.
# Affichage des détails de chaque compte :
# Afficher le solde, le taux d’intérêt et la date de la dernière application des intérêts.
# Sécurité avec code PIN :
# Lors de l’accès à un compte, l’utilisateur doit entrer le code PIN correspondant pour effectuer des actions.

#------------------------------------------------ Debut du code ------------------------------------------------
import datetime
from typing import List, Dict

# Ce script implémente un gestionnaire de banque simplifié avec les fonctionnalités suivantes :
# - Création de comptes bancaires avec solde initial, taux d'intérêt et code PIN
# - Opérations de base : consultation du solde, dépôt, retrait
# - Historique des transactions
# - Application automatique des intérêts mensuels
# - Transferts entre comptes
# - Affichage des détails de tous les comptes
# - Sécurité avec vérification du code PIN pour chaque opération

class Compte:
    """
    Représente un compte bancaire individuel.
    """
    def __init__(self, nom: str, solde_initial: float, taux_interet: float, pin: str):
        """
        Initialise un nouveau compte bancaire.
        """
        self.nom = nom
        self.solde = solde_initial
        self.taux_interet = taux_interet
        self.pin = pin
        self.historique: List[str] = []
        self.derniere_application_interet = datetime.date.today()

    def verifier_pin(self, pin: str) -> bool:
        """
        Vérifie si le PIN fourni correspond au PIN du compte.
        """
        return self.pin == pin

    def deposer(self, montant: float) -> None:
        """
        Dépose un montant sur le compte et met à jour l'historique.
        """
        self.solde += montant
        self.historique.append(f"Dépôt de {montant}€ - Nouveau solde: {self.solde}€")

    def retirer(self, montant: float) -> bool:
        """
        Retire un montant du compte si le solde est suffisant et met à jour l'historique.
        """
        if self.solde >= montant:
            self.solde -= montant
            self.historique.append(f"Retrait de {montant}€ - Nouveau solde: {self.solde}€")
            return True
        return False

    def appliquer_interet(self) -> None:
        """
        Applique l'intérêt mensuel au solde du compte si un nouveau mois a commencé.
        """
        aujourd_hui = datetime.date.today()
        if aujourd_hui.month != self.derniere_application_interet.month:
            interet = self.solde * (self.taux_interet / 100)
            self.solde += interet
            self.historique.append(f"Intérêt appliqué: {interet}€ - Nouveau solde: {self.solde}€")
            self.derniere_application_interet = aujourd_hui

class GestionnaireBanque:
    """
    Gère l'ensemble des comptes bancaires et les opérations entre comptes.
    """
    def __init__(self):
        """
        Initialise le gestionnaire de banque avec un dictionnaire vide de comptes.
        """
        self.comptes: Dict[str, Compte] = {}

    def creer_compte(self, nom: str, solde_initial: float, taux_interet: float, pin: str) -> None:
        """
        Crée un nouveau compte bancaire s'il n'existe pas déjà.
        """
        if nom not in self.comptes:
            self.comptes[nom] = Compte(nom, solde_initial, taux_interet, pin)
            print(f"Compte '{nom}' créé avec succès.")
        else:
            print(f"Un compte avec le nom '{nom}' existe déjà.")

    def acceder_compte(self, nom: str, pin: str) -> Compte:
        """
        Accède à un compte existant après vérification du PIN.
        """
        if nom in self.comptes:
            compte = self.comptes[nom]
            if compte.verifier_pin(pin):
                return compte
            else:
                print("PIN incorrect.")
        else:
            print(f"Le compte '{nom}' n'existe pas.")
        return None

    def transferer(self, nom_source: str, nom_cible: str, montant: float, pin: str) -> bool:
        """
        Transfère un montant d'un compte source vers un compte cible.
        """
        compte_source = self.acceder_compte(nom_source, pin)
        if compte_source:
            if nom_cible in self.comptes:
                if compte_source.retirer(montant):
                    self.comptes[nom_cible].deposer(montant)
                    print(f"Transfert de {montant}€ de '{nom_source}' à '{nom_cible}' effectué.")
                    return True
                else:
                    print("Solde insuffisant pour effectuer le transfert.")
            else:
                print(f"Le compte cible '{nom_cible}' n'existe pas.")
        return False

    def afficher_details_comptes(self) -> None:
        """
        Affiche les détails de tous les comptes gérés par la banque.
        """
        for nom, compte in self.comptes.items():
            print(f"Compte: {nom}")
            print(f"  Solde: {compte.solde}€")
            print(f"  Taux d'intérêt: {compte.taux_interet}%")
            print(f"  Dernière application d'intérêt: {compte.derniere_application_interet}")
            print()

def menu_principal():
    """
    Affiche le menu principal et retourne le choix de l'utilisateur.
    """
    print("\n--- Menu Principal ---")
    print("1. Créer un compte")
    print("2. Accéder à un compte")
    print("3. Transférer de l'argent")
    print("4. Afficher les détails des comptes")
    print("5. Quitter")
    return input("Choisissez une option: ")

def menu_compte():
    """
    Affiche le menu du compte et retourne le choix de l'utilisateur.
    """
    print("\n--- Menu du Compte ---")
    print("1. Consulter le solde")
    print("2. Déposer de l'argent")
    print("3. Retirer de l'argent")
    print("4. Afficher l'historique")
    print("5. Retour au menu principal")
    return input("Choisissez une option: ")

def main():
    """
    Fonction principale qui gère l'interaction avec l'utilisateur.
    """
    banque = GestionnaireBanque()

    while True:
        choix = menu_principal()

        if choix == '1':
            # Création d'un nouveau compte
            nom = input("Nom du compte: ")
            solde_initial = float(input("Solde initial: "))
            taux_interet = float(input("Taux d'intérêt (%): "))
            pin = input("Créez un code PIN: ")
            banque.creer_compte(nom, solde_initial, taux_interet, pin)

        elif choix == '2':
            # Accès à un compte existant
            nom = input("Nom du compte: ")
            pin = input("Entrez le code PIN: ")
            compte = banque.acceder_compte(nom, pin)
            if compte:
                while True:
                    choix_compte = menu_compte()
                    if choix_compte == '1':
                        print(f"Solde actuel: {compte.solde}€")
                    elif choix_compte == '2':
                        montant = float(input("Montant à déposer: "))
                        compte.deposer(montant)
                        print(f"Dépôt de {montant}€ effectué.")
                    elif choix_compte == '3':
                        montant = float(input("Montant à retirer: "))
                        if compte.retirer(montant):
                            print(f"Retrait de {montant}€ effectué.")
                        else:
                            print("Solde insuffisant.")
                    elif choix_compte == '4':
                        print("\nHistorique des transactions:")
                        for transaction in compte.historique:
                            print(transaction)
                    elif choix_compte == '5':
                        break
                    else:
                        print("Option invalide. Veuillez réessayer.")

        elif choix == '3':
            # Transfert d'argent entre comptes
            nom_source = input("Nom du compte source: ")
            nom_cible = input("Nom du compte cible: ")
            montant = float(input("Montant à transférer: "))
            pin = input("Entrez le code PIN du compte source: ")
            banque.transferer(nom_source, nom_cible, montant, pin)

        elif choix == '4':
            # Affichage des détails de tous les comptes
            banque.afficher_details_comptes()

        elif choix == '5':
            # Sortie du programme
            print("Merci d'avoir utilisé notre service bancaire. Au revoir!")
            break

        else:
            # Gestion des options invalides
            print("Option invalide. Veuillez réessayer.")

if __name__ == "__main__":
    main()

# %%
#Gestion des différentes erreurs (Exceptions)
def ecrire_dans_fichier(file, content):
    try:
        with open(file, 'w') as f:
            f.write(content)
    except FileNotFoundError: # Erreur si le fichier n'existe pas
        print("Erreur: Fichier non trouvé.")
    except PermissionError: # Erreur si l'utilisateur n'a pas la permission
        print("Erreur: Permission refusée pour écrire dans le fichier.")
    except Exception as e: # Autres erreurs inattendues
        print(f"Erreur inattendue: {e}")    
        
# test
ecrire_dans_fichier("test.txt", "Hello, World!")
